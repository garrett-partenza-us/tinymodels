# %%
import cv2

# %%
large = cv2.imread("image.jpg")
large = cv2.resize(large, (1024,1024))

small = cv2.imread("image.jpg")
small = cv2.resize(small, (400,400))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
plt.imshow(large)

# %%
plt.imshow(small)

# %%
cv2.imwrite("large.jpg", large)
# Out:
# True

# %%
cv2.imwrite("small.jpg", small)
# Out:
# True
