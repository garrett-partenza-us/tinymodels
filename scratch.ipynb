# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train = np.load("vit/losstrain.npy")
test = np.load("vit/losseval.npy")

# %%
plt.figure(figsize=(12,6))
plt.plot(train, label="train")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(test, label="eval")
plt.legend()
plt.show()
